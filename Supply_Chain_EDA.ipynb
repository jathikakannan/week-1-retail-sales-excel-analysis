# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Everything is working!")
# Out:
# Everything is working!

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jathika\\OneDrive\\Desktop\\Supply-Chain-Analytics'

# %%
import pandas as pd

df = pd.read_csv("dataset/SCMS Delivery History Dataset.csv")
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
df.head(10)
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# 5  23   112-NG-T01  Pre-PQ Process   SCMS-87   ASN-57        Nigeria
# 6  44   110-ZM-T01  Pre-PQ Process  SCMS-139  ASN-130         Zambia
# 7  45   109-TZ-T01  Pre-PQ Process  SCMS-140   ASN-94       Tanzania
# 8  46   112-NG-T01  Pre-PQ Process  SCMS-156   ASN-93        Nigeria
# 9  47   110-ZM-T01  Pre-PQ Process  SCMS-165  ASN-199         Zambia
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# ...

# %%
df.shape
# Out:
# (10324, 33)

# %%
list(df.columns)
# Out:
# ['ID',
#  'Project Code',
#  'PQ #',
#  'PO / SO #',
#  'ASN/DN #',
#  'Country',
#  'Managed By',
#  'Fulfill Via',
#  'Vendor INCO Term',
#  'Shipment Mode',
#  'PQ First Sent to Client Date',
#  'PO Sent to Vendor Date',
#  'Scheduled Delivery Date',
#  'Delivered to Client Date',
#  'Delivery Recorded Date',
#  'Product Group',
#  'Sub Classification',
#  'Vendor',
#  'Item Description',
#  'Molecule/Test Type',
#  'Brand',
#  'Dosage',
#  'Dosage Form',
#  'Unit of Measure (Per Pack)',
#  'Line Item Quantity',
#  'Line Item Value',
#  'Pack Price',
#  'Unit Price',
#  'Manufacturing Site',
#  'First Line Designation',
#  'Weight (Kilograms)',
#  'Freight Cost (USD)',
#  'Line Item Insurance (USD)']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# ID                                int64
# Project Code                     object
# PQ #                             object
# PO / SO #                        object
# ASN/DN #                         object
# Country                          object
# Managed By                       object
# Fulfill Via                      object
# Vendor INCO Term                 object
# Shipment Mode                    object
# PQ First Sent to Client Date     object
# PO Sent to Vendor Date           object
# Scheduled Delivery Date          object
# Delivered to Client Date         object
# Delivery Recorded Date           object
# Product Group                    object
# Sub Classification               object
# Vendor                           object
# Item Description                 object
# Molecule/Test Type               object
# Brand                            object
# Dosage                           object
# Dosage Form                      object
# ...

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'Project Code',
#  'PQ #',
#  'PO / SO #',
#  'ASN/DN #',
#  'Country',
#  'Managed By',
#  'Fulfill Via',
#  'Vendor INCO Term',
#  'Shipment Mode',
#  'PQ First Sent to Client Date',
#  'PO Sent to Vendor Date',
#  'Scheduled Delivery Date',
#  'Delivered to Client Date',
#  'Delivery Recorded Date',
#  'Product Group',
#  'Sub Classification',
#  'Vendor',
#  'Item Description',
#  'Molecule/Test Type',
#  'Brand',
#  'Dosage',
#  'Dosage Form',
#  'Unit of Measure (Per Pack)',
#  'Line Item Quantity',
#  'Line Item Value',
#  'Pack Price',
#  'Unit Price',
#  'Manufacturing Site',
#  'First Line Designation',
#  'Weight (Kilograms)',
#  'Freight Cost (USD)',
#  'Line Item Insurance (USD)']

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
df.dtypes
# Out:
# ID                                int64
# Project Code                     object
# PQ #                             object
# PO / SO #                        object
# ASN/DN #                         object
# Country                          object
# Managed By                       object
# Fulfill Via                      object
# Vendor INCO Term                 object
# Shipment Mode                    object
# PQ First Sent to Client Date     object
# PO Sent to Vendor Date           object
# Scheduled Delivery Date          object
# Delivered to Client Date         object
# Delivery Recorded Date           object
# Product Group                    object
# Sub Classification               object
# Vendor                           object
# Item Description                 object
# Molecule/Test Type               object
# Brand                            object
# Dosage                           object
# Dosage Form                      object
# ...

# %%
date_columns = [
    'PQ First Sent to Client Date',
    'PO Sent to Vendor Date',
    'Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Recorded Date'
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

df[date_columns].dtypes
# Out:
# C:\Users\jathika\AppData\Local\Temp\ipykernel_1868\1206233756.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\jathika\AppData\Local\Temp\ipykernel_1868\1206233756.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\jathika\AppData\Local\Temp\ipykernel_1868\1206233756.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# ...

# %%
numeric_columns = [
    'Weight (Kilograms)',
    'Freight Cost (USD)',
    'Unit Price',
    'Line Item Value',
    'Pack Price',
    'Line Item Insurance (USD)'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df[numeric_columns].dtypes
# Out:
# Weight (Kilograms)           float64
# Freight Cost (USD)           float64
# Unit Price                   float64
# Line Item Value              float64
# Pack Price                   float64
# Line Item Insurance (USD)    float64
# dtype: object

# %%
df[numeric_columns] = df[numeric_columns].fillna(
    df[numeric_columns].median()
)

# %%
object_columns = df.select_dtypes(include='object').columns

df[object_columns] = df[object_columns].fillna("Unknown")

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 10324 non-null  object
#  10  PQ First Sent to Client Date  7643 non-null   datetime64[ns]
#  11  PO Sent to Vendor Date        4592 non-null   datetime64[ns]
# ...

# %%
df['Shipment Mode'].value_counts()
# Out:
# Shipment Mode
# Air            6113
# Truck          2830
# Air Charter     650
# Ocean           371
# Unknown         360
# Name: count, dtype: int64

# %%
country_shipments = df['Country'].value_counts()

country_shipments
# Out:
# Country
# South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Guatemala               15
# Pakistan                15
# Malawi                  14
# Benin                   13
# Lebanon                  8
# Libya                    8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# ...

# %%
df['Delivery Delay'] = (
    df['Delivered to Client Date'] -
    df['Scheduled Delivery Date']
).dt.days

# %%
df[['Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Delay']].head()
# Out:
#   Scheduled Delivery Date Delivered to Client Date  Delivery Delay
# 0              2006-06-02               2006-06-02               0
# 1              2006-11-14               2006-11-14               0
# 2              2006-08-27               2006-08-27               0
# 3              2006-09-01               2006-09-01               0
# 4              2006-08-11               2006-08-11               0

# %%
df['Delivery Delay'].mean()
# Out:
# np.float64(-6.023537388609066)

# %%
delayed_shipments = df[df['Delivery Delay'] > 0]

delayed_shipments.head()
# Out:
#        ID Project Code            PQ #   PO / SO #  ASN/DN #       Country  \
# 24    130   100-HT-T01  Pre-PQ Process  SCMS-10080   ASN-628         Haiti
# 72    772   131-NG-T01  Pre-PQ Process  SCMS-30502  ASN-3653       Nigeria
# 122  1196   102-BW-T01  Pre-PQ Process  SCMS-46071  ASN-4324      Botswana
# 144  1307   102-NG-T01  Pre-PQ Process    SCMS-343   ASN-259       Nigeria
# 202  1926   116-ZA-T01  Pre-PQ Process  SCMS-26820  ASN-2487  South Africa
#
#     Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 24    PMO - US  Direct Drop              EXW           Air  ...
# 72    PMO - US  Direct Drop              CIP           Air  ...
# 122   PMO - US  Direct Drop              EXW           Air  ...
# 144   PMO - US  Direct Drop              EXW           Air  ...
# 202   PMO - US  Direct Drop              DDP         Truck  ...
#
#     Line Item Quantity Line Item Value Pack Price Unit Price  \
# 24                 750         53992.5      71.99       0.72
# ...

# %%
df['Freight Cost (USD)'].sum()
# Out:
# np.float64(93036045.94)

# %%
df['Line Item Value'].mean()
# Out:
# np.float64(157650.56734695853)

# %%
df['Line Item Insurance (USD)'].sum()
# Out:
# np.float64(2423561.09)

# %%
country_shipments = df.groupby('Country').size()

country_shipments.sort_values(ascending=False)
# Out:
# Country
# South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Pakistan                15
# Guatemala               15
# Malawi                  14
# Benin                   13
# Lebanon                  8
# Libya                    8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# ...

# %%
vendor_cost = df.groupby('Vendor')['Freight Cost (USD)'].sum()

vendor_cost.sort_values(ascending=False)
# Out:
# Vendor
# SCMS from RDC                                            4.776189e+07
# Orgenics, Ltd                                            1.072671e+07
# Aurobindo Pharma Limited                                 5.919107e+06
# S. BUYS WHOLESALER                                       4.188081e+06
# MYLAN LABORATORIES LTD (FORMERLY MATRIX LABORATORIES)    3.580857e+06
#                                                              ...
# RANBAXY Fine Chemicals LTD.                              1.639870e+03
# CENTRAL PHARMACEUTICAL COMPANY NO. 1                     1.401490e+03
# B&C GROUP S.A.                                           1.200580e+03
# OMEGA DIAGNOSTICS LTD                                    6.337300e+02
# ABBOTT LABORATORIES (PUERTO RICO)                        3.140000e+02
# Name: Freight Cost (USD), Length: 73, dtype: float64

# %%
product_value = df.groupby('Product Group')['Line Item Value'].sum()

product_value.sort_values(ascending=False)
# Out:
# Product Group
# ARV     1.413220e+09
# HRDT    2.133448e+08
# ACT     6.643809e+05
# ANTM    2.741766e+05
# MRDT    8.106510e+04
# Name: Line Item Value, dtype: float64

# %%
shipment_delay = df.groupby('Shipment Mode')['Delivery Delay'].mean()

shipment_delay
# Out:
# Shipment Mode
# Air            -3.763782
# Air Charter   -19.036923
# Ocean           5.870620
# Truck          -9.921908
# Unknown        -2.511111
# Name: Delivery Delay, dtype: float64

# %%
df['Shipment Mode'].value_counts()
# Out:
# Shipment Mode
# Air            6113
# Truck          2830
# Air Charter     650
# Ocean           371
# Unknown         360
# Name: count, dtype: int64

# %%
df['Shipment Mode'].mode()
# Out:
# 0    Air
# Name: Shipment Mode, dtype: object

# %%
country_shipments = df['Country'].value_counts()
country_shipments
# Out:
# Country
# South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Guatemala               15
# Pakistan                15
# Malawi                  14
# Benin                   13
# Lebanon                  8
# Libya                    8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# ...

# %%
df['Delivery Delay'] = (
    df['Delivered to Client Date'] -
    df['Scheduled Delivery Date']
).dt.days

# %%
df[['Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Delay']].head()
# Out:
#   Scheduled Delivery Date Delivered to Client Date  Delivery Delay
# 0              2006-06-02               2006-06-02               0
# 1              2006-11-14               2006-11-14               0
# 2              2006-08-27               2006-08-27               0
# 3              2006-09-01               2006-09-01               0
# 4              2006-08-11               2006-08-11               0

# %%
df['Delivery Delay'].mean()
# Out:
# np.float64(-6.023537388609066)

# %%
delayed_shipments = df[df['Delivery Delay'] > 0]
delayed_shipments.head()
# Out:
#        ID Project Code            PQ #   PO / SO #  ASN/DN #       Country  \
# 24    130   100-HT-T01  Pre-PQ Process  SCMS-10080   ASN-628         Haiti
# 72    772   131-NG-T01  Pre-PQ Process  SCMS-30502  ASN-3653       Nigeria
# 122  1196   102-BW-T01  Pre-PQ Process  SCMS-46071  ASN-4324      Botswana
# 144  1307   102-NG-T01  Pre-PQ Process    SCMS-343   ASN-259       Nigeria
# 202  1926   116-ZA-T01  Pre-PQ Process  SCMS-26820  ASN-2487  South Africa
#
#     Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 24    PMO - US  Direct Drop              EXW           Air  ...
# 72    PMO - US  Direct Drop              CIP           Air  ...
# 122   PMO - US  Direct Drop              EXW           Air  ...
# 144   PMO - US  Direct Drop              EXW           Air  ...
# 202   PMO - US  Direct Drop              DDP         Truck  ...
#
#     Line Item Quantity Line Item Value Pack Price Unit Price  \
# 24                 750         53992.5      71.99       0.72
# ...

# %%
len(delayed_shipments)
# Out:
# 1186

# %%
df['Freight Cost (USD)'].sum()
# Out:
# np.float64(93036045.94)

# %%
df['Line Item Value'].mean()
# Out:
# np.float64(157650.56734695853)

# %%
df['Line Item Insurance (USD)'].sum()
# Out:
# np.float64(2423561.09)

# %%
country_shipments = (
    df.groupby('Country')
      .size()
      .sort_values(ascending=False)
)

country_shipments
# Out:
# Country
# South Africa          1406
# Nigeria               1194
# Côte d'Ivoire         1083
# Uganda                 779
# Vietnam                688
# Zambia                 683
# Haiti                  655
# Mozambique             631
# Zimbabwe               538
# Tanzania               519
# Rwanda                 430
# Congo, DRC             333
# Guyana                 237
# Ethiopia               216
# South Sudan            164
# Kenya                  111
# Burundi                 98
# Namibia                 95
# Cameroon                75
# Botswana                70
# Ghana                   58
# Dominican Republic      52
# Sudan                   46
# Swaziland               35
# Mali                    17
# Pakistan                15
# Guatemala               15
# Malawi                  14
# Benin                   13
# Lebanon                  8
# Libya                    8
# Angola                   7
# Liberia                  6
# Lesotho                  4
# ...

# %%
vendor_cost = (
    df.groupby('Vendor')['Freight Cost (USD)']
      .sum()
      .sort_values(ascending=False)
)

vendor_cost
# Out:
# Vendor
# SCMS from RDC                                            4.776189e+07
# Orgenics, Ltd                                            1.072671e+07
# Aurobindo Pharma Limited                                 5.919107e+06
# S. BUYS WHOLESALER                                       4.188081e+06
# MYLAN LABORATORIES LTD (FORMERLY MATRIX LABORATORIES)    3.580857e+06
#                                                              ...
# RANBAXY Fine Chemicals LTD.                              1.639870e+03
# CENTRAL PHARMACEUTICAL COMPANY NO. 1                     1.401490e+03
# B&C GROUP S.A.                                           1.200580e+03
# OMEGA DIAGNOSTICS LTD                                    6.337300e+02
# ABBOTT LABORATORIES (PUERTO RICO)                        3.140000e+02
# Name: Freight Cost (USD), Length: 73, dtype: float64

# %%
product_value = (
    df.groupby('Product Group')['Line Item Value']
      .sum()
      .sort_values(ascending=False)
)

product_value
# Out:
# Product Group
# ARV     1.413220e+09
# HRDT    2.133448e+08
# ACT     6.643809e+05
# ANTM    2.741766e+05
# MRDT    8.106510e+04
# Name: Line Item Value, dtype: float64

# %%
shipment_delay = (
    df.groupby('Shipment Mode')['Delivery Delay']
      .mean()
      .sort_values()
)

shipment_delay
# Out:
# Shipment Mode
# Air Charter   -19.036923
# Truck          -9.921908
# Air            -3.763782
# Unknown        -2.511111
# Ocean           5.870620
# Name: Delivery Delay, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
country_shipments = df['Country'].value_counts().head(10)

plt.figure(figsize=(10,6))

country_shipments.plot(kind='bar')

plt.title("Top 10 Countries by Total Shipments")

plt.xlabel("Country")

plt.ylabel("Number of Shipments")

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
shipment_mode = df['Shipment Mode'].value_counts()

plt.figure(figsize=(8,8))

shipment_mode.plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Shipment Mode Distribution")

plt.ylabel("")

plt.show()

# %%
delivery_trend = (
    df.groupby('Delivered to Client Date')
      .size()
)

plt.figure(figsize=(12,6))

delivery_trend.plot()

plt.title("Delivery Trend Over Time")

plt.xlabel("Delivery Date")

plt.ylabel("Number of Deliveries")

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
df.to_csv("Supply_Chain_Cleaned.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.qodo',
#  'dataset',
#  'notebooks',
#  'Supply_Chain_Cleaned.csv',
#  'Untitled.ipynb',
#  'venv']
